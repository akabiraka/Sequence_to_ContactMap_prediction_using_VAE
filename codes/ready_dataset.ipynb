# %%
import os
import constants as CONSTANTS

# %%
from pdb_converter import PDBConverter
pdb_converter = PDBConverter(CONSTANTS.ALL_PDB_IDS)
pdb_converter.apply()
# Out:
# Structure exists: '../pdbs/6y2d.cif'
# Can not resolve distance:  SER SER
# Traceback (most recent call last):
#   File "/media/akabir/New Volume/phd/research work/prof_amarda_shehu/protein_project_1/codes/pdb_converter.py", line 222, in compute_res_res_distance
#     diff_vector = residue_1["CB"].coord - residue_2["CB"].coord
#   File "/media/akabir/New Volume/python3_venv/lib/python3.6/site-packages/Bio/PDB/Entity.py", line 42, in __getitem__
#     return self.child_dict[id]
# KeyError: 'CB'
# Structure exists: '../pdbs/5sy8.cif'
# 1 , 5sy8 =====:  155
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-88f0e614f7ce> in <module>
#       1 from pdb_converter import PDBConverter
#       2 pdb_converter = PDBConverter(CONSTANTS.ALL_PDB_IDS)
# ----> 3 pdb_converter.apply()
#
# /media/akabir/New Volume/phd/research work/prof_amarda_shehu/protein_project_1/codes/pdb_converter.py in apply(self)
#      94                         if count % self.view_every == 0:
#      95                             # draws dist_matrix, contact_map
# ---> 96                             self.view(pdb_chain_id)
#      97             if count == self.keep_n_pdbs:
#      98                 break
#
# /media/akabir/New Volume/phd/research work/prof_amarda_shehu/protein_project_1/codes/pdb_converter.py in view(self, pdb_chain_id)
#     277         titles = ["distance matrix", "contact map"]
#     278         Utility.plot_images(images, pdb_chain_id, titles,
# --> 279                             cols=2, save_plt=self.save_plt)
#     280         # self.__plot_images(images, filename, titles, cols=2)
#     281
#
# /media/akabir/New Volume/phd/research work/prof_amarda_shehu/protein_project_1/codes/utility.py in plot_images(images, img_name, titles, cols, save_plt)
#      66     # plt.show()
#      67     if save_plt:
# ---> 68         plt.savefig("output_images/{}.png".format(img_name))
#      69
#      70
#
# /media/akabir/New Volume/python3_venv/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /media/akabir/New Volume/python3_venv/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /media/akabir/New Volume/python3_venv/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2103                     orientation=orientation,
#    2104                     bbox_inches_restore=_bbox_inches_restore,
# -> 2105                     **kwargs)
#    2106             finally:
#    2107                 if bbox_inches and restore_bbox:
#
# /media/akabir/New Volume/python3_venv/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# /media/akabir/New Volume/python3_venv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /media/akabir/New Volume/python3_venv/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_images/5sy8O.png'

# %%
# from pdb_converter import PDBConverter
# pdb_converter = PDBConverter(CONSTANTS.TRAIN_FILE)
# pdb_converter.convert_into_fasta()

# %%
from feature_generator import FeatureGenerator
feature_generator = FeatureGenerator(CONSTANTS.N_PDB_IDS)
feature_generator.one_hot()
# Out:
# 5sy8O:  torch.Size([155, 20])
# 4eiuA:  torch.Size([238, 20])
# 3t47A:  torch.Size([71, 20])
# 5lwaA:  torch.Size([148, 20])
# 4lx3A:  torch.Size([98, 20])
# 1ihjA:  torch.Size([94, 20])
# 3l1nA:  torch.Size([152, 20])
# 5m1pA:  torch.Size([187, 20])
# 5fv6A:  torch.Size([168, 20])
# 3h6rA:  torch.Size([152, 20])

# %%
from data_spliter import DataSpliter
data_spliter = DataSpliter(CONSTANTS.N_PDB_IDS)
data_spliter.split()
# Out:
# train size: 6 val size: 2 test size: 2
# (['3t47A', '5m1pA', '3h6rA', '4lx3A', '4eiuA', '5lwaA'],
#  ['3l1nA', '1ihjA'],
#  ['5fv6A', '5sy8O'])
